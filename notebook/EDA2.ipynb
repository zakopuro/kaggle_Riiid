# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm import tqdm

# %%
train_df = pd.read_csv('../data/input/train.csv', low_memory=False)

# %%
train_df.head()
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            3                   1                          NaN
# 1            2                   1                      37000.0
# 2            0                   1                      55000.0
# 3            0                   1                      19000.0
# 4            1                   1                      11000.0
#
#   prior_question_had_explanation
# 0                            NaN
# 1                          False
# 2                          False
# 3                          False
# 4                          False

# %%
qs = pd.read_csv('../data/input/questions.csv')

# %%
lc = pd.read_csv('../data/input/lectures_new.csv')

# %%
tag = qs["tags"].str.split(" ",expand = True)

# %%
tag.columns = ['tags1','tags2','tags3','tags4','tags5','tags6']

# %%
tag.head()
# Out:
#   tags1 tags2 tags3 tags4 tags5 tags6
# 0    51   131   162    38  None  None
# 1   131    36    81  None  None  None
# 2   131   101   162    92  None  None
# 3   131   149   162    29  None  None
# 4   131     5   162    38  None  None

# %%
qs = pd.concat([qs,tag],axis=1)

# %%
qs.head()
# Out:
#    question_id  bundle_id  correct_answer  part            tags tags1 tags2  \
# 0            0          0               0     1   51 131 162 38    51   131
# 1            1          1               1     1       131 36 81   131    36
# 2            2          2               0     1  131 101 162 92   131   101
# 3            3          3               0     1  131 149 162 29   131   149
# 4            4          4               3     1    131 5 162 38   131     5
#
#   tags3 tags4 tags5 tags6
# 0   162    38  None  None
# 1    81  None  None  None
# 2   162    92  None  None
# 3   162    29  None  None
# 4   162    38  None  None

# %%
lc.head()
# Out:
#    lecture_id  tag  part           type_of
# 0          89  159     5           concept
# 1         100   70     1           concept
# 2         185   45     6           concept
# 3         192   79     5  solving question
# 4         317  156     5  solving question

# %%
def _label_encoder(data):
    l_data,_ =data.factorize(sort=True)
    if l_data.max()>32000:
        l_data = l_data.astype('int32')
    else:
        l_data = l_data.astype('int16')

    if data.isnull().sum() > 0:
        l_data = np.where(l_data == -1,np.nan,l_data)
    return l_data

# %%
lc['l_type_of'] = _label_encoder(lc['type_of'])

# %%
lc.head()
# Out:
#    lecture_id  tag  part           type_of  l_type_of
# 0          89  159     5           concept          0
# 1         100   70     1           concept          0
# 2         185   45     6           concept          0
# 3         192   79     5  solving question          2
# 4         317  156     5  solving question          2

# %%
qs = qs.rename(columns={'question_id':'content_id'})
lc = lc.rename(columns={'lecture_id':'content_id'})

# %%
qs = qs[['content_id','part','tags1','tags2','tags3','tags4','tags5','tags6']]

# %%
qs_lc = pd.concat([qs,lc])
# Out:
# /home/zakopuro/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
qs_lc
# Out:
#      content_id  l_type_of  part    tag tags1 tags2 tags3 tags4 tags5 tags6  \
# 0             0        NaN     1    NaN    51   131   162    38  None  None
# 1             1        NaN     1    NaN   131    36    81  None  None  None
# 2             2        NaN     1    NaN   131   101   162    92  None  None
# 3             3        NaN     1    NaN   131   149   162    29  None  None
# 4             4        NaN     1    NaN   131     5   162    38  None  None
# ..          ...        ...   ...    ...   ...   ...   ...   ...   ...   ...
# 413       32535        2.0     5    8.0   NaN   NaN   NaN   NaN   NaN   NaN
# 414       32570        2.0     3  113.0   NaN   NaN   NaN   NaN   NaN   NaN
# 415       32604        0.0     6   24.0   NaN   NaN   NaN   NaN   NaN   NaN
# 416       32625        0.0     2  142.0   NaN   NaN   NaN   NaN   NaN   NaN
# 417       32736        0.0     3   82.0   NaN   NaN   NaN   NaN   NaN   NaN
#
#               type_of
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 413  solving question
# 414  solving question
# 415           concept
# 416           concept
# 417           concept
#
# [13941 rows x 11 columns]

# %%
train_df = pd.merge(train_df,qs_lc,on='content_id',how='left')

# %%
train_df.head()
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            3                   1                          NaN
# 1            2                   1                      37000.0
# 2            0                   1                      55000.0
# 3            0                   1                      19000.0
# 4            1                   1                      11000.0
#
#   prior_question_had_explanation  l_type_of  part  tag tags1 tags2 tags3  \
# 0                            NaN        NaN     5  NaN   151  None  None
# 1                          False        NaN     5  NaN   168  None  None
# 2                          False        NaN     1  NaN   131   149    92
# 3                          False        NaN     1  NaN   131   104    81
# 4                          False        NaN     1  NaN   131   149    92
#
#   tags4 tags5 tags6 type_of
# 0  None  None  None     NaN
# 1  None  None  None     NaN
# 2  None  None  None     NaN
# 3  None  None  None     NaN
# 4  None  None  None     NaN

# %%
user_ans_mean = train_df[train_df['tag'].isnull()][['user_id','answered_correctly']].groupby('user_id').mean()

# %%
user_part_ans_mean = train_df[train_df['tag'].isnull()][['user_id','part','answered_correctly']].groupby(['user_id','part']).mean()

# %%
# Out:
#               answered_correctly
# user_id part
# 115     1               0.702703
#         2               1.000000
#         3               0.666667
#         4               0.333333
#         5               1.000000
